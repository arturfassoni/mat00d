# %% [markdown]
# ## Vídeos

# %% [markdown]
# Para complementar o que vimos neste capítulo, seguem sugestões de algumas videoaulas de outros professores e canais sobre os temas deste capítulo. Clique em uma miniatura para assistir no YouTube.

# %% [markdown]
# ### Modelagem

# %% [markdown]
# <div style="display:grid; grid-template-columns: repeat(auto-fill, minmax(220px, 1fr)); gap: 20px 16px; margin: 14px 0 24px 0;">
#   <a href="https://www.youtube.com/watch?v=EakgST1_3cQ&list=PLJVeWGwSovVlApnOgJQgM4LckRMswNxKy&index=8" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/EakgST1_3cQ/hqdefault.jpg" alt="EDO-007 Aplicações - Equações Diferenciais 1ª Ordem" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>EDO-007 Aplicações - Equações Diferenciais 1ª Ordem</strong><br>
#       <span style="color:#777;">Matemática Universitária</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=F3kT0rPxofQ&list=PLmtT_GZAQdt-5S4XTXSd3U-G8udumDM2R&index=12" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/F3kT0rPxofQ/hqdefault.jpg" alt="Modelagem com EDOs de Primeira Ordem: Crescimento e Decrescimento + Meia-Vida" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>Modelagem com EDOs de Primeira Ordem: Crescimento e Decrescimento + Meia-Vida</strong><br>
#       <span style="color:#777;">Matemateca - Ester Velasquez</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=uMH6mrboR8Y&list=PLmtT_GZAQdt-5S4XTXSd3U-G8udumDM2R&index=13" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/uMH6mrboR8Y/hqdefault.jpg" alt="Modelagem com EDOs de Primeira Ordem: Lei de Resfriamento de Newton e Circuitos Elétricos" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>Modelagem com EDOs de Primeira Ordem: Lei de Resfriamento de Newton e Circuitos Elétricos</strong><br>
#       <span style="color:#777;">Matemateca - Ester Velasquez</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=_u2FXHQiHM0&list=PLmtT_GZAQdt-5S4XTXSd3U-G8udumDM2R&index=14" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/_u2FXHQiHM0/hqdefault.jpg" alt="Modelagem com EDOs de Primeira Ordem: Mistura de Soluções" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>Modelagem com EDOs de Primeira Ordem: Mistura de Soluções</strong><br>
#       <span style="color:#777;">Matemateca - Ester Velasquez</span>
#     </div>
#   </a>
# </div>

# %% [markdown]
# ### Equações Lineares

# %% [markdown]
# <div style="display:grid; grid-template-columns: repeat(auto-fill, minmax(220px, 1fr)); gap: 20px 16px; margin: 14px 0 24px 0;">
#   <a href="https://www.youtube.com/watch?v=lVJ0rlmNFOQ&list=PLJVeWGwSovVlApnOgJQgM4LckRMswNxKy&index=4" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/lVJ0rlmNFOQ/hqdefault.jpg" alt="EDO-004 Equações Diferenciais Lineares" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>EDO-004 Equações Diferenciais Lineares</strong><br>
#       <span style="color:#777;">Matemática Universitária</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=gjetfdNl_fs&list=PLmtT_GZAQdt-5S4XTXSd3U-G8udumDM2R&index=8" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/gjetfdNl_fs/hqdefault.jpg" alt="EDOs Lineares de Primeira Ordem: Método de Resolução e Exemplos Resolvidos" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>EDOs Lineares de Primeira Ordem: Método de Resolução e Exemplos Resolvidos</strong><br>
#       <span style="color:#777;">Matemateca - Ester Velasquez</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=8OZnLTwkWJo&list=PLmtT_GZAQdt-5S4XTXSd3U-G8udumDM2R&index=9" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/8OZnLTwkWJo/hqdefault.jpg" alt="O passo a passo para resolver EDOs Lineares: Exercícios Resolvidos" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>O passo a passo para resolver EDOs Lineares: Exercícios Resolvidos</strong><br>
#       <span style="color:#777;">Matemateca - Ester Velasquez</span>
#     </div>
#   </a>
# </div>

# %% [markdown]
# ### Equações Separáveis

# %% [markdown]
# <div style="display:grid; grid-template-columns: repeat(auto-fill, minmax(220px, 1fr)); gap: 20px 16px; margin: 14px 0 24px 0;">
#   <a href="https://www.youtube.com/watch?v=67mhCNLB5Nc&list=PLJVeWGwSovVlApnOgJQgM4LckRMswNxKy&index=3" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/67mhCNLB5Nc/hqdefault.jpg" alt="EDO-003 Equações Diferenciais Separáveis" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>EDO-003 Equações Diferenciais Separáveis</strong><br>
#       <span style="color:#777;">Matemática Universitária</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=TZe-2XFKaaI&list=PLmtT_GZAQdt-5S4XTXSd3U-G8udumDM2R&index=5" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/TZe-2XFKaaI/hqdefault.jpg" alt="EDOs Separáveis: Método de Resolução e Exercícios Resolvidos" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>EDOs Separáveis: Método de Resolução e Exercícios Resolvidos</strong><br>
#       <span style="color:#777;">Matemateca - Ester Velasquez</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=R0ncvZnTkuk&list=PLmtT_GZAQdt-5S4XTXSd3U-G8udumDM2R&index=6" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/R0ncvZnTkuk/hqdefault.jpg" alt="EDOs Separáveis: Exercícios Resolvidos Passo a Passo" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>EDOs Separáveis: Exercícios Resolvidos Passo a Passo</strong><br>
#       <span style="color:#777;">Matemateca - Ester Velasquez</span>
#     </div>
#   </a>
# </div>

# %% [markdown]
# ### Equações Autônomas

# %% [markdown]
# <div style="display:grid; grid-template-columns: repeat(auto-fill, minmax(220px, 1fr)); gap: 20px 16px; margin: 14px 0 24px 0;">
#   <a href="https://www.youtube.com/watch?v=NiOdKczefyo&list=PLRod2w6vHFp50uEFCX9aH0aYnyNbYgni8&index=5" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/NiOdKczefyo/hqdefault.jpg" alt="Equações Diferenciais Ordinárias Não Lineares - Parte 1" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>Equações Diferenciais Ordinárias Não Lineares - Parte 1</strong><br>
#       <span style="color:#777;">Artur Fassoni</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=j5JpwETSirc&list=PLRod2w6vHFp50uEFCX9aH0aYnyNbYgni8&index=6" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/j5JpwETSirc/hqdefault.jpg" alt="Equações Diferenciais Ordinárias Não Lineares - Parte 2" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>Equações Diferenciais Ordinárias Não Lineares - Parte 2</strong><br>
#       <span style="color:#777;">Artur Fassoni</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=Z_hOoxj2Vq4&list=PLRod2w6vHFp50uEFCX9aH0aYnyNbYgni8&index=7" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/Z_hOoxj2Vq4/hqdefault.jpg" alt="Modelos de EDOs Não Lineares para Dinâmica de Populações" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>Modelos de EDOs Não Lineares para Dinâmica de Populações</strong><br>
#       <span style="color:#777;">Artur Fassoni</span>
#     </div>
#   </a>
# </div>
