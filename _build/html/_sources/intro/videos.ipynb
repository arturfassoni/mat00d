# %% [markdown]
# ## Vídeos

# %% [markdown]
# Para complementar o que vimos neste capítulo, seguem alguns vídeos externos (aulas em vídeo de outros professores e canais) sobre os temas desta introdução. Clique em uma miniatura para assistir no YouTube. $ $

# %% [markdown]
# <div style="display:grid; grid-template-columns: repeat(auto-fill, minmax(220px, 1fr)); gap: 20px 16px; margin: 14px 0 24px 0;">
#   <a href="https://www.youtube.com/watch?v=p_di4Zn4wz4" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/p_di4Zn4wz4/hqdefault.jpg" alt="Differential equations, a tourist's guide | DE1" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>Differential equations, a tourist's guide | DE1</strong><br>
#       <span style="color:#777;">3Blue1Brown</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=TTKaNcFrDEw&list=PLt9oVGXH7c4B39vNFyFvqJwg7cqbn5OrK&index=1" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/TTKaNcFrDEw/hqdefault.jpg" alt="O que é uma Equação Diferencial? — Ep. 01" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>O que é uma Equação Diferencial? — Ep. 01</strong><br>
#       <span style="color:#777;">Professor Julio Lombaldo</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=mq4z2SH7oDc&list=PLt9oVGXH7c4B39vNFyFvqJwg7cqbn5OrK&index=2" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/mq4z2SH7oDc/hqdefault.jpg" alt="O que é o Campo de Direções de uma Equação Diferencial — Ep. 02" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>O que é o Campo de Direções de uma Equação Diferencial — Ep. 02</strong><br>
#       <span style="color:#777;">Professor Julio Lombaldo</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=ErGTFCViVMQ&list=PLJVeWGwSovVlApnOgJQgM4LckRMswNxKy&index=1" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/ErGTFCViVMQ/hqdefault.jpg" alt="EDO-001 Introdução às Equações Diferenciais" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>EDO-001 Introdução às Equações Diferenciais</strong><br>
#       <span style="color:#777;">Matemática Universitária</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=7NyPuRgeWGk&list=PLJVeWGwSovVlApnOgJQgM4LckRMswNxKy&index=2" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/7NyPuRgeWGk/hqdefault.jpg" alt="EDO-002 Soluções de Equações Diferenciais" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>EDO-002 Soluções de Equações Diferenciais</strong><br>
#       <span style="color:#777;">Matemática Universitária</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=lempeC72Tyg&list=PLFBA21F349930F92F&index=1" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/lempeC72Tyg/hqdefault.jpg" alt="Cálculo III — Introdução (Parte 1)" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>Cálculo III — Introdução (Parte 1)</strong><br>
#       <span style="color:#777;">UNIVESP</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=YGnSXbp8fcU&list=PLt9oVGXH7c4B39vNFyFvqJwg7cqbn5OrK&index=4" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/YGnSXbp8fcU/hqdefault.jpg" alt="Quando existe e é única uma solução de uma equação diferencial - Ep.04" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>Quando existe e é única uma solução de uma equação diferencial - Ep.04</strong><br>
#       <span style="color:#777;">Professor Julio Lombaldo</span>
#     </div>
#   </a>
#   <a href="https://www.youtube.com/watch?v=aev6NYtIIow&list=PLmtT_GZAQdt-5S4XTXSd3U-G8udumDM2R&index=2" target="_blank" rel="noopener" style="text-decoration:none; color:inherit;">
#     <div style="position:relative; border-radius:10px; overflow:hidden; box-shadow:0 1px 4px rgba(0,0,0,0.25);">
#       <img src="https://i.ytimg.com/vi/aev6NYtIIow/hqdefault.jpg" alt="Quando o PVI possui solução única?: Existência e Unicidade" style="width:100%; display:block;">
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:0; height:0; border-top:12px solid transparent; border-bottom:12px solid transparent;
#                   border-left:20px solid rgba(255,255,255,0.9);"></div>
#       <div style="position:absolute; top:50%; left:50%; transform:translate(-50%,-50%);
#                   width:56px; height:56px; border-radius:50%; background:rgba(0,0,0,0.35); z-index:-1;"></div>
#     </div>
#     <div style="font-size:0.92em; margin-top:6px; line-height:1.3;">
#       <strong>Quando o PVI possui solução única?: Existência e Unicidade</strong><br>
#       <span style="color:#777;">Matemateca - Ester Velasquez</span>
#     </div>
#   </a>
# </div>
